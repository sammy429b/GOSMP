# %%
import pandas as pd
import numpy as np
import datetime as datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
timed_df = pd.read_csv("close_all.csv")
timed_df.fillna(0, inplace=True)

timed_df['Date'] = pd.to_datetime(timed_df['Date'])
timed_df.set_index('Date', inplace=True)

# Drop columns where every entry is 0.0
timed_df = timed_df.loc[:, (timed_df != 0).any(axis=0)]

# # # Use the column selection to drop columns where less than the threshold number of values are non-zero
threshold = 0.70 * len(timed_df)
timed_df = timed_df.loc[:, (timed_df != 0).sum() >= threshold]

# %%
timed_df
# Out:
#                     ABB    AEGISLOG  AMARAJABAT  AMBALALSA  ANDHRAPET  \
# Date
# 2000-01-03    53.989998    0.000000    0.000000   0.000000   0.000000
# 2000-01-04    52.599998    0.000000    0.000000   0.000000   0.000000
# 2000-01-05    52.200001    0.000000    0.000000   0.000000   0.000000
# 2000-01-06    56.000000    0.000000    0.000000   0.000000   0.000000
# 2000-01-07    54.000000    0.000000    0.000000   0.000000   0.000000
# ...                 ...         ...         ...        ...        ...
# 2023-10-06  4132.799805  326.799988  644.150024  40.500000  77.339996
# 2023-10-09  4095.149902  322.700012  634.549988  41.310001  74.269997
# 2023-10-10  4189.149902  323.299988  635.250000  42.130001  74.580002
# 2023-10-11  4187.649902  323.450012  641.950012  42.970001  75.910004
# 2023-10-12  4215.350098  323.049988  648.049988  43.820000  75.739998
#
#             ANSALAPI  ARUNAHTEL   BOMDYEING  ASIANHOTNR         ATUL  ...  \
# Date                                                                  ...
# 2000-01-03       0.0  96.300003   14.839999    0.000000     0.000000  ...
# 2000-01-04       0.0  96.300003   14.579999    0.000000     0.000000  ...
# 2000-01-05       0.0  96.300003   13.799999    0.000000     0.000000  ...
# 2000-01-06       0.0  96.300003   14.189999    0.000000     0.000000  ...
# 2000-01-07       0.0  96.300003   13.299999    0.000000     0.000000  ...
# ...              ...        ...         ...         ...          ...  ...
# 2023-10-06       0.0  15.870000  145.449997  139.600006  7027.399902  ...
# 2023-10-09      14.3  14.930000  141.300003  129.649994  6889.799805  ...
# 2023-10-10       0.0  15.000000  149.949997  133.500000  6882.899902  ...
# 2023-10-11       0.0  14.700000  154.500000  133.050003  6897.299805  ...
# 2023-10-12       0.0  16.170000  155.399994  146.350006  6944.200195  ...
#
#               BENGALASM  SUNDARAM     TAMBOLI  KCPSUGIND        KECL  \
# Date
# 2000-01-03     0.000000      0.00    0.000000   0.000000    0.000000
# 2000-01-04     0.000000      0.00    0.000000   0.000000    0.000000
# 2000-01-05     0.000000      0.00    0.000000   0.000000    0.000000
# 2000-01-06     0.000000      0.00    0.000000   0.000000    0.000000
# 2000-01-07     0.000000      0.00    0.000000   0.000000    0.000000
# ...                 ...       ...         ...        ...         ...
# 2023-10-06  5626.049805      3.44  170.050003  35.900002  126.050003
# 2023-10-09  5610.049805      3.36  168.300003  36.660000  127.150002
# 2023-10-10  5645.899902      3.34  178.000000  38.480000  130.899994
# 2023-10-11  5804.200195      3.37  176.399994  38.000000  131.699997
# 2023-10-12  5901.149902      3.39  187.750000  37.529999  128.199997
#
#                  KTIL      ZENTEC    APLAPOLLO   TERASOFT  STEELXIND
# Date
# 2000-01-03   0.000000    0.000000     0.000000   0.000000       0.00
# 2000-01-04   0.000000    0.000000     0.000000   0.000000       0.00
# 2000-01-05   0.000000    0.000000     0.000000   0.000000       0.00
# 2000-01-06   0.000000    0.000000     0.000000   0.000000       0.00
# 2000-01-07   0.000000    0.000000     0.000000   0.000000       0.00
# ...               ...         ...          ...        ...        ...
# 2023-10-06  55.049999  728.250000  1617.050049  46.310001       8.80
# 2023-10-09  55.000000  709.450012  1572.150024  44.180000       7.98
# 2023-10-10  52.730000  744.900024  1615.250000  47.060001       8.49
# 2023-10-11  51.520000  740.400024  1668.949951  45.650002       9.35
# 2023-10-12  53.330002  728.750000  1675.400024  46.959999       9.63
#
# [5859 rows x 1856 columns]

# %%
# Assuming timed_df is your DataFrame indexed by date

# Set the desired start and end dates
start_date = '2010-01-01'
end_date = '2019-01-01'

# Use loc to select rows within the specified date range
timed_df = timed_df.loc[start_date:end_date]

# Set the desired number of columns to keep
num_columns_to_keep = 100 #Replace with your desired number

# first num columns
# timed_df = timed_df.iloc[:, :num_columns_to_keep]

# last num columns 
# timed_df = timed_df.iloc[:, -num_columns_to_keep:]

#random num columns
timed_df = timed_df.sample(n=num_columns_to_keep, axis=1)


timed_df.columns
# Out:
# Index(['NAGREEKEXP', 'NIPPOBATRY', 'TAJGVK', 'KAMAHOLD', 'INDTONER', 'TANLA',
#        'VASINFRA', 'NDLVENTURE', 'SRAMSET', 'IITLPROJ', 'CRANESSOFT',
#        'VINATIORGA', 'REPRO', 'GOGIACAP', 'CENTUM', 'GEECEE', 'ROSELABS',
#        'KIDUJA', '63MOONS', 'CGCL', 'SWASTIVI', 'DRAGARWQ', 'URJAGLOBA',
#        'SUCROSA', 'MAHAANF', 'STEELXIND', 'RELICTEC', 'MARIS', 'SIYSIL',
#        'KUSHIND', 'MAHLIFE', 'NKIND', 'ADMANUM', 'NAHARINDUS', 'ADINATH',
#        'GAEL', 'TRISHAKT', 'INDAGIV', 'PRADPME', 'YASHRAJC', 'PRATIKSH',
#        'ESHAMEDIA', 'HBPOR', 'LIMECHM', 'ANSALBU', 'BAMPSL', 'LAKSELEC',
#        'PRECISION', 'BEEYU', 'SYBLY', 'INDIANACRY', 'KRYPTONQ', 'APOLLOHOSP',
#        'KCPSUGIND', 'CARNATIN', 'UNOMINDA', 'SELAN', 'DEEPAKFERT', 'ROYALCU',
#        'SDL', 'GANESHBE', 'MANORG', 'TUTIALKA', 'TYROON', 'GUJALKALI',
#        'SANWARIA', 'DCBBANK', 'ENERGYDEV', 'CENTURYTEX', 'UNIVARTS', 'DLTNCBL',
#        'ELNET', 'GRANULES', 'SAYAJIHOTL', 'JINDHOT', 'PREMCAP', 'PBMPOLY',
#        'ALFAVIO', 'MDRNSTL', 'BLACKROSE', 'IFBIND', 'NELCO', 'CHANDRAP',
#        'INDGELA', 'VOLTAMP', 'MAFATIND', 'ACGL', 'LAXMIMACH', 'VIJAYTX',
#        'UNRYLMA', 'XCHANGING', 'WHIRLPOOL', 'DATASOFT', 'KTIL', 'GIPCL',
#        'BAMBINO', 'ELECTHERM', 'QUADRANT', 'SANDUPHQ', 'SHIVTEX'],
#       dtype='object')

# %%
timed_df
# Out:
#             NAGREEKEXP  NIPPOBATRY      TAJGVK     KAMAHOLD    INDTONER  \
# Date
# 2010-01-04   21.450001  211.175003  148.949997   269.950012   28.600000
# 2010-01-05   22.450001  218.949997  148.199997   273.500000   28.299999
# 2010-01-06   22.100000  219.425003  152.800003   275.000000   27.900000
# 2010-01-07   22.400000  220.750000  156.350006   279.350006   28.450001
# 2010-01-08   22.200001  221.725006  155.449997   271.850006   29.049999
# ...                ...         ...         ...          ...         ...
# 2018-12-26   24.100000  355.649994  179.100006  5025.500000  142.850006
# 2018-12-27   23.950001  357.500000  180.250000  5100.000000  142.199997
# 2018-12-28    0.000000  360.000000  179.800003  5144.000000  144.000000
# 2018-12-31   23.299999  357.825012  175.399994  5349.750000  147.199997
# 2019-01-01    0.000000  365.000000  178.500000  5339.049805  149.100006
#
#                 TANLA   VASINFRA  NDLVENTURE     SRAMSET   IITLPROJ  ...  \
# Date                                                                 ...
# 2010-01-04  61.599998  24.750000  354.200012   24.250000  36.400002  ...
# 2010-01-05  63.200001  23.799999  360.000000   23.350000  36.400002  ...
# 2010-01-06  64.750000  22.799999  366.299988   24.000000  36.400002  ...
# 2010-01-07  63.299999  21.549999  365.399994   24.150000  34.599998  ...
# 2010-01-08  62.650002  23.250000  368.299988   25.250000  33.000000  ...
# ...               ...        ...         ...         ...        ...  ...
# 2018-12-26  30.600000   4.790000  410.049988  184.000000  27.900000  ...
# 2018-12-27  30.100000   4.790000  414.000000  175.000000  27.900000  ...
# 2018-12-28  30.750000   4.790000  418.950012  168.649994  27.900000  ...
# 2018-12-31  30.549999   4.790000  410.600006  177.000000  27.900000  ...
# 2019-01-01  30.700001   4.790000  415.299988  184.800003  27.900000  ...
#
#             XCHANGING    WHIRLPOOL  DATASOFT        KTIL       GIPCL  \
# Date
# 2010-01-04  92.699997   138.199997      2.80  107.349998  119.750000
# 2010-01-05  92.349998   136.300003      2.80  110.000000  129.250000
# 2010-01-06  92.050003   140.000000      2.80  115.699997  127.000000
# 2010-01-07  91.300003   137.100006      2.80  114.849998  123.500000
# 2010-01-08  90.900002   141.300003      2.80  111.750000  120.900002
# ...               ...          ...       ...         ...         ...
# 2018-12-26  46.000000  1308.500000      1.13   67.300003   76.750000
# 2018-12-27  45.549999  1326.550049      1.13   68.000000   77.199997
# 2018-12-28  45.950001  1373.849976      1.13   68.500000   78.500000
# 2018-12-31  45.150002  1394.599976      1.13   69.000000   78.199997
# 2019-01-01  46.450001  1406.300049      1.13   68.949997   80.000000
#
#                BAMBINO   ELECTHERM  QUADRANT   SANDUPHQ     SHIVTEX
# Date
# 2010-01-04   37.349998  278.649994      7.69  15.900000   34.049999
# 2010-01-05   37.500000  292.950012      7.62  15.550000   33.500000
# 2010-01-06   35.650002  343.600006      7.72  15.200000   33.950001
# 2010-01-07   35.500000  327.149994      7.62  15.300000   34.599998
# 2010-01-08   36.049999  345.600006      7.50  15.200000   33.700001
# ...                ...         ...       ...        ...         ...
# 2018-12-26  198.250000  151.449997      0.49  25.850000  196.000000
# 2018-12-27  204.699997  153.149994      0.48  24.799999  197.050003
# 2018-12-28  194.500000  152.350006      0.48  24.000000  192.949997
# 2018-12-31  191.350006  150.000000      0.46  24.000000  199.899994
# 2019-01-01  199.199997  150.699997      0.46  23.900000  198.449997
#
# [2217 rows x 100 columns]

# %%
# Show daily returns
returns = timed_df.pct_change()
returns.fillna(0, inplace=True)
returns.replace([np.inf, -np.inf], 0, inplace=True)

returns
# Out:
#             NAGREEKEXP  NIPPOBATRY    TAJGVK  KAMAHOLD  INDTONER     TANLA  \
# Date
# 2010-01-04    0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-01-05    0.046620    0.036818 -0.005035  0.013151 -0.010490  0.025974
# 2010-01-06   -0.015590    0.002169  0.031039  0.005484 -0.014134  0.024525
# 2010-01-07    0.013575    0.006038  0.023233  0.015818  0.019713 -0.022394
# 2010-01-08   -0.008929    0.004417 -0.005756 -0.026848  0.021090 -0.010269
# ...                ...         ...       ...       ...       ...       ...
# 2018-12-26    0.000000   -0.021394  0.001398 -0.015120 -0.011076 -0.009709
# 2018-12-27   -0.006224    0.005202  0.006421  0.014824 -0.004550 -0.016340
# 2018-12-28   -1.000000    0.006993 -0.002497  0.008627  0.012658  0.021595
# 2018-12-31    0.000000   -0.006042 -0.024472  0.039998  0.022222 -0.006504
# 2019-01-01   -1.000000    0.020052  0.017674 -0.002000  0.012908  0.004910
#
#             VASINFRA  NDLVENTURE   SRAMSET  IITLPROJ  ...  XCHANGING  \
# Date                                                  ...
# 2010-01-04  0.000000    0.000000  0.000000  0.000000  ...   0.000000
# 2010-01-05 -0.038384    0.016375 -0.037113  0.000000  ...  -0.003776
# 2010-01-06 -0.042017    0.017500  0.027837  0.000000  ...  -0.003248
# 2010-01-07 -0.054825   -0.002457  0.006250 -0.049451  ...  -0.008148
# 2010-01-08  0.078886    0.007936  0.045549 -0.046243  ...  -0.004381
# ...              ...         ...       ...       ...  ...        ...
# 2018-12-26  0.000000    0.000000 -0.036649  0.000000  ...   0.022222
# 2018-12-27  0.000000    0.009633 -0.048913  0.000000  ...  -0.009783
# 2018-12-28  0.000000    0.011957 -0.036286  0.000000  ...   0.008782
# 2018-12-31  0.000000   -0.019931  0.049511  0.000000  ...  -0.017410
# 2019-01-01  0.000000    0.011447  0.044068  0.000000  ...   0.028793
#
#             WHIRLPOOL  DATASOFT      KTIL     GIPCL   BAMBINO  ELECTHERM  \
# Date
# 2010-01-04   0.000000       0.0  0.000000  0.000000  0.000000   0.000000
# 2010-01-05  -0.013748       0.0  0.024686  0.079332  0.004016   0.051319
# 2010-01-06   0.027146       0.0  0.051818 -0.017408 -0.049333   0.172896
# 2010-01-07  -0.020714       0.0 -0.007347 -0.027559 -0.004208  -0.047875
# 2010-01-08   0.030635       0.0 -0.026992 -0.021053  0.015493   0.056396
# ...               ...       ...       ...       ...       ...        ...
# 2018-12-26   0.011206       0.0 -0.043355 -0.005185  0.016927  -0.002962
# 2018-12-27   0.013794       0.0  0.010401  0.005863  0.032535   0.011225
# 2018-12-28   0.035656       0.0  0.007353  0.016839 -0.049829  -0.005224
# 2018-12-31   0.015104       0.0  0.007299 -0.003822 -0.016195  -0.015425
# 2019-01-01   0.008390       0.0 -0.000725  0.023018  0.041024   0.004667
#
#             QUADRANT  SANDUPHQ   SHIVTEX
# Date
# 2010-01-04  0.000000  0.000000  0.000000
# 2010-01-05 -0.009103 -0.022013 -0.016153
# 2010-01-06  0.013123 -0.022508  0.013433
# 2010-01-07 -0.012953  0.006579  0.019146
# 2010-01-08 -0.015748 -0.006536 -0.026011
# ...              ...       ...       ...
# 2018-12-26 -0.039216  0.063786  0.031036
# 2018-12-27 -0.020408 -0.040619  0.005357
# 2018-12-28  0.000000 -0.032258 -0.020807
# 2018-12-31 -0.041667  0.000000  0.036020
# 2019-01-01  0.000000 -0.004167 -0.007254
#
# [2217 rows x 100 columns]

# %%
# Annualized covariance matrix

# cov_matrix_annual = returns.cov()*252
cov_matrix_annual = returns.cov()*246
cov_matrix_annual.fillna(0, inplace=True)
cov_matrix_annual
# Out:
#             NAGREEKEXP  NIPPOBATRY    TAJGVK  KAMAHOLD  INDTONER     TANLA  \
# NAGREEKEXP    9.614060    0.177522  0.034540  0.079794  0.017785  0.114921
# NIPPOBATRY    0.177522    1.683476  0.011617  0.245768  0.228625  0.020268
# TAJGVK        0.034540    0.011617  0.173400  0.016928  0.023396  0.043405
# KAMAHOLD      0.079794    0.245768  0.016928  0.441206  0.247861  0.034248
# INDTONER      0.017785    0.228625  0.023396  0.247861  0.563225  0.040132
# ...                ...         ...       ...       ...       ...       ...
# BAMBINO       0.023672    0.222744  0.015963  0.235459  0.244456  0.028664
# ELECTHERM     0.387109   -0.021333  0.033937  0.037442 -0.040730  0.086530
# QUADRANT      0.035048    0.249601  0.024419  0.242832  0.259079  0.056866
# SANDUPHQ      0.071333    0.242207  0.021308  0.243498  0.251846  0.035736
# SHIVTEX       0.069304    0.267160  0.040325  0.259165  0.263318  0.057347
#
#             VASINFRA  NDLVENTURE   SRAMSET  IITLPROJ  ...  XCHANGING  \
# NAGREEKEXP  0.102063    0.150133 -0.039447 -0.011985  ...   0.041476
# NIPPOBATRY  0.269790    0.142544  0.218525  0.217263  ...   0.047635
# TAJGVK      0.029127    0.024753 -0.003184 -0.000612  ...   0.025511
# KAMAHOLD    0.255241    0.019250  0.225964  0.220113  ...   0.034941
# INDTONER    0.274574    0.017951  0.221883  0.223446  ...   0.050470
# ...              ...         ...       ...       ...  ...        ...
# BAMBINO     0.237528    0.023298  0.223394  0.225355  ...   0.030330
# ELECTHERM   0.020699    0.010830  0.008844 -0.001734  ...   0.067331
# QUADRANT    0.244841    0.023201  0.233043  0.227956  ...   0.038787
# SANDUPHQ    0.243338    0.023740  0.223637  0.229623  ...   0.029832
# SHIVTEX     0.254028    0.041071  0.232093  0.230794  ...   0.046828
#
#             WHIRLPOOL  DATASOFT      KTIL     GIPCL   BAMBINO  ELECTHERM  \
# NAGREEKEXP   0.038422  0.023539  0.025371  0.032080  0.023672   0.387109
# NIPPOBATRY   0.018562  0.218215  0.244495  0.016155  0.222744  -0.021333
# TAJGVK       0.021710  0.002186  0.019063  0.023203  0.015963   0.033937
# KAMAHOLD     0.013285  0.238927  0.243952  0.018018  0.235459   0.037442
# INDTONER     0.017457  0.223779  0.265925  0.029038  0.244456  -0.040730
# ...               ...       ...       ...       ...       ...        ...
# BAMBINO      0.013608  0.255924  0.243109  0.017759  0.500874   0.063594
# ELECTHERM    0.021351  0.024911 -0.001100  0.029054  0.063594   3.585764
# QUADRANT     0.025432  0.249239  0.248791  0.022035  0.250218  -0.000237
# SANDUPHQ     0.013772  0.226117  0.243018  0.016904  0.239563   0.010660
# SHIVTEX      0.032720  0.215362  0.272996  0.031945  0.257637   0.020526
#
#             QUADRANT  SANDUPHQ   SHIVTEX
# NAGREEKEXP  0.035048  0.071333  0.069304
# NIPPOBATRY  0.249601  0.242207  0.267160
# TAJGVK      0.024419  0.021308  0.040325
# KAMAHOLD    0.242832  0.243498  0.259165
# INDTONER    0.259079  0.251846  0.263318
# ...              ...       ...       ...
# BAMBINO     0.250218  0.239563  0.257637
# ELECTHERM  -0.000237  0.010660  0.020526
# QUADRANT    0.648805  0.246873  0.267077
# SANDUPHQ    0.246873  0.529230  0.258090
# SHIVTEX     0.267077  0.258090  0.552049
#
# [100 rows x 100 columns]

# %%
weights = np.full(timed_df.shape[1], 1 / timed_df.shape[1])
weights
# Out:
# array([0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01])

# %%
# Calculate PORTFOLIO variance
port_variance = np.dot(weights.T, np.dot(cov_matrix_annual, weights))
port_variance
# Out:
# 0.13005896964474617

# %%
# Calculate PORTFOLIO volatility (std. dev)
port_volatility = np.sqrt(port_variance)
port_volatility
# Out:
# 0.36063689445860386

# %%
# Annual portfolio return
portfolioSimpleAnnualReturn = np.sum(returns.mean() * weights) * 252
portfolioSimpleAnnualReturn
# Out:
# -0.4488960350604767

# %%
# DISPLAY

percent_var = str(round(port_variance, 2)*100) + "%"
percent_vol = str(round(port_volatility, 2)*100) + "%"
percent_ret = str(round(portfolioSimpleAnnualReturn, 2)*100) + "%"

print ("Expected Annual Return: " + percent_ret)
print ("Annual Volatility: " + percent_vol)
print ("Annual Variance: " + percent_var)
# Out:
# Expected Annual Return: -45.0%
# Annual Volatility: 36.0%
# Annual Variance: 13.0%

# %% [markdown]
# # OPTIMIZATION

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
mu = expected_returns.mean_historical_return(timed_df, frequency=252)

# mu = expected_returns.ema_historical_return(timed_df)

# mu = expected_returns.return_model(timed_df)


# mu = expected_returns.capm_return(timed_df)


mu.fillna(0, inplace = True)
mu.replace(np.inf, 0.0, inplace=True)

# %%
# S = risk_models.sample_cov(timed_df)

S = risk_models.exp_cov(timed_df)

# S = risk_models.CovarianceShrinkage(timed_df)

# S = (S + S.T) / 2

S.fillna(0, inplace = True)
S.replace(np.inf, 0.0, inplace=True)

# %%
# S_normalized
# S_f = (S + S.T) / 2

#S_reg
S_f = S + 1e-6 * np.eye(S.shape[0])

# %%
# ef = EfficientFrontier(mu, S)
ef = EfficientFrontier(mu, S_f, solver="ECOS")
# solvers: ECOS, OSQP

# weights = ef.max_sharpe()


# Maximize Return for a Target Volatility:
# weights = ef.efficient_return(target_return=0.10)

# Minimize Volatility for a Target Return:
weights = ef.efficient_risk(target_volatility=0.30)

refined_weights = ef.clean_weights()

# %%
print ()
print ()
print ("-----PORTFOLIO PERFORMANCE-----")
print ()


ef.portfolio_performance(verbose = True)


print ()
print ()
print ("-----ASSET ALLOCATION-----")
print ()


refined_weights = {key: value for key, value in refined_weights.items() if value != 0.0}

# Normalize the percentages
total_weight = sum(refined_weights.values())
refined_weights_percent = {key: (value / total_weight) * 100 for key, value in refined_weights.items()}

for key, value in refined_weights_percent.items():
    print(f"{key}: {value:.2f}%")
# Out:
# -----PORTFOLIO PERFORMANCE-----
#
# Expected annual return: 37.4%
# Annual volatility: 30.0%
# Sharpe Ratio: 1.18
#
#
# -----ASSET ALLOCATION-----
#
# VINATIORGA: 50.32%
# GAEL: 5.23%
# IFBIND: 21.47%
# WHIRLPOOL: 22.98%
